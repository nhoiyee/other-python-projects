# %%
import pandas as pd

df=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/IMDB-Movie-Data.csv')

df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.Rank.describe()
# Out:
# count    1000.000000
# mean      500.500000
# std       288.819436
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: Rank, dtype: float64

# %% [markdown]
# ### 1. create 2 seperate columns (hour, minute) from Runtime column.

# %%
df['Hour']=df['Runtime (Minutes)']//60

# %%
df['Minutes']=df['Runtime (Minutes)']%60

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.Hour*60+df.Minutes
# Out:
# 0      121
# 1      124
# 2      117
# 3      108
# 4      123
#       ...
# 995    111
# 996     94
# 997     98
# 998     93
# 999     87
# Length: 1000, dtype: int64

# %% [markdown]
# ### 2. what is the longest and shortest movie?

# %%
df['Runtime (Minutes)'].max()
# Out:
# 191

# %%
df['Runtime (Minutes)'].min()
# Out:
# 66

# %%
df.loc[df['Runtime (Minutes)'].idxmax()]
# Out:
# Rank                                                                829
# Title                                                        Grindhouse
# Genre                                            Action,Horror,Thriller
# Description           Quentin Tarantino and Robert Rodriguez's homag...
# Director                                               Robert Rodriguez
# Actors                Kurt Russell, Rose McGowan, Danny Trejo, Zoë Bell
# Year                                                               2007
# Runtime (Minutes)                                                   191
# Rating                                                              7.6
# Votes                                                            160350
# Revenue (Millions)                                                25.03
# Metascore                                                           NaN
# Hour                                                                  3
# ...

# %%
df.loc[df['Runtime (Minutes)'].idxmax()].Title
# Out:
# 'Grindhouse'

# %%
df.loc[df['Runtime (Minutes)'].idxmin()].Title
# Out:
# 'Ma vie de Courgette'

# %% [markdown]
# ### 3. the first 5 shortest movies

# %%
df.loc[df['Runtime (Minutes)'].nsmallest().index]
# Out:
#      Rank                    Title                   Genre  \
# 793   794      Ma vie de Courgette  Animation,Comedy,Drama
# 42     43  Don't Fuck in the Woods                  Horror
# 819   820       Wolves at the Door         Horror,Thriller
# 711   712          La tortue rouge       Animation,Fantasy
# 949   950                    Kicks               Adventure
#
#                                            Description              Director  \
# 793  After losing his mother, a young boy is sent t...         Claude Barras
# 42   A group of friends are going on a camping trip...         Shawn Burkett
# 819  Four friends gather at an elegant home during ...      John R. Leonetti
# 711  A man is shipwrecked on a deserted island and ...  Michael Dudok de Wit
# 949  Brandon is a 15 year old whose dream is a pair...        Justin Tipping
#
#                                                 Actors  Year  \
# 793  Gaspard Schlatter, Sixtine Murat, Paulin Jacco...  2016
# ...

# %% [markdown]
# ### 4. find the longest movie in 2016

# %%
df.loc[df.Year==2016]
# Out:
#      Rank                           Title                     Genre  \
# 2       3                           Split           Horror,Thriller
# 3       4                            Sing   Animation,Comedy,Family
# 4       5                   Suicide Squad  Action,Adventure,Fantasy
# 5       6                  The Great Wall  Action,Adventure,Fantasy
# 6       7                      La La Land        Comedy,Drama,Music
# ..    ...                             ...                       ...
# 975   976      My Big Fat Greek Wedding 2     Comedy,Family,Romance
# 977   978                   Amateur Night                    Comedy
# 978   979  It's Only the End of the World                     Drama
# 980   981            Miracles from Heaven    Biography,Drama,Family
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# ...

# %%
df.loc[df.Year==2016]['Runtime (Minutes)'].max()
# Out:
# 163

# %%
df.loc[df['Runtime (Minutes)']==163]
# Out:
#      Rank           Title  Genre  \
# 225   226  American Honey  Drama
#
#                                            Description       Director  \
# 225  A teenage girl with nothing to lose joins a tr...  Andrea Arnold
#
#                                                 Actors  Year  \
# 225  Sasha Lane, Shia LaBeouf, Riley Keough, McCaul...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore  Hour  \
# 225                163     7.0  19660                0.66       79.0     2
#
#      Minutes
# 225       43

# %%
df.loc[df['Runtime (Minutes)']==163].Title
# Out:
# 225    American Honey
# Name: Title, dtype: object

# %% [markdown]
# ### 5. what is the average, medium, var for all the movies

# %%
df.Rating.mean()
# Out:
# 6.723199999999999

# %%
df.Rating.median()
# Out:
# 6.8

# %%
df.Rating.var()
# Out:
# 0.8938355955955956
