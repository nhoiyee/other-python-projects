# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_01.csv')

# %%
df
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df2=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_02.csv',header=None,names=['fname','lname','course','score'])

# %%
df2
# Out:
#            fname      lname      course  score
# 0          Alex       Smith     Python      92
# 1         James       Jones        C++      97
# 2          Mary    Williams     Python      98
# 3      Patricia       Brown       Java      87
# 4      Jennifer      Taylor       HTML      88
# 5         Emily      Davies   Android       90
# 6       Michael      Wilson     Python      91
# 7       Jessica       Evans        C++      95
# 8          John      Thomas     Python      90
# 9        Thomas     Roberts       Java      89
# 10  Christopher      Martin     Python      83
# 11      Barbara         Lee        C++      86
# 12      Matthew    Anderson          R      97
# 13         Mark       White     Python      91
# 14        Nancy      Taylor       Java      96
# 15       Andrew       Smith          R      92

# %%
df1=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_01.csv',skiprows=1,
names=['a','b','c','d'])
df1
# Out:
#                a          b           c   d
# 0          Alex       Smith     Python   92
# 1         James       Jones        C++   97
# 2          Mary    Williams     Python   98
# 3      Patricia       Brown       Java   87
# 4      Jennifer      Taylor       HTML   88
# 5         Emily      Davies   Android    90
# 6       Michael      Wilson     Python   91
# 7       Jessica       Evans        C++   95
# 8          John      Thomas     Python   90
# 9        Thomas     Roberts       Java   89
# 10  Christopher      Martin     Python   83
# 11      Barbara         Lee        C++   86
# 12      Matthew    Anderson          R   97
# 13         Mark       White     Python   91
# 14        Nancy      Taylor       Java   96
# 15       Andrew       Smith          R   92

# %%
df3=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_03.csv')
df3
# Out:
#    first name| last name| experience| score
# 0                 Alex | Smith| Python | 92
# 1                   James | Jones| C++ | 97
# 2              Mary | Williams| Python | 98
# 3               Patricia | Brown| Java | 87
# 4              Jennifer | Taylor| HTML | 88
# 5             Emily | Davies| Android  | 90
# 6             Michael | Wilson| Python | 91
# 7                 Jessica | Evans| C++ | 95
# 8                John | Thomas| Python | 90
# 9               Thomas | Roberts| Java | 89
# 10        Christopher | Martin| Python | 83
# 11                  Barbara | Lee| C++ | 86
# 12               Matthew | Anderson| R | 97
# 13                Mark | White| Python | 91
# 14                Nancy | Taylor| Java | 96
# 15                   Andrew | Smith| R | 92

# %%
len(df3.columns)
# Out:
# 1

# %%
df3=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_03.csv',sep='|')
df3
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df4=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_04.csv',comment='#')
df4
# Out:
#    first name\t last name\t experience\t score
# 0                 Alex \t Smith\t Python \t 92
# 1                   James \t Jones\t C++ \t 97
# 2              Mary \t Williams\t Python \t 98
# 3               Patricia \t Brown\t Java \t 87
# 4              Jennifer \t Taylor\t HTML \t 88
# 5             Emily \t Davies\t Android  \t 90
# 6             Michael \t Wilson\t Python \t 91
# 7                 Jessica \t Evans\t C++ \t 95
# 8                John \t Thomas\t Python \t 90
# 9               Thomas \t Roberts\t Java \t 89
# 10        Christopher \t Martin\t Python \t 83
# 11                  Barbara \t Lee\t C++ \t 86
# 12               Matthew \t Anderson\t R \t 97
# 13                Mark \t White\t Python \t 91
# 14                Nancy \t Taylor\t Java \t 96
# 15                   Andrew \t Smith\t R \t 92

# %%
df4=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_04.csv',comment='#',sep='\t')
df4
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df5=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_05.csv')
# Out:
# -------------------------------------------------------------------
# ParserError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df5=pd.read_csv('/Users/Hoi Yee/Downloads/Datasets/data_05.csv')
#
# File c:\users\hoi yee\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py:685, in _make_parser_function.<locals>.parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
